# %% [markdown]
# # Actividad evaluable: Mapas de calor y boxplots

# %% [markdown]
# En esta actividad trabajaras con el conjunto de datos asignado para el reto. Tienes que replicar los pasos vistos durante las horas de salón en un diferente conjunto de datos.

# %% [markdown]
# Carga los datos usando tu lector de csv o con pandas. Es recomendable hacerlo con pandas:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

datos = pd.read_csv("covid19_tweets.csv")

# %% [markdown]
# Realiza el análisis de las variables usando diagramas de cajas y bigotes, histogramas y mapas de calor:

# %% [markdown]
# Diagrama de cajas y bigotes:

# %%
plt.boxplot(datos[["user_followers","user_friends","user_favourites"]])

plt.show()

# %%
import seaborn as sns
sns.boxplot(datos[["user_followers","user_friends","user_favourites"]], showfliers=False)
# Out:
# c:\Users\pinki\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\pinki\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\pinki\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: >

# %% [markdown]
# Histograma:

# %%
ax = datos[["user_followers","user_friends","user_favourites"]].plot.hist(bins=60, alpha=1)

# %% [markdown]
# Mapa de calor:

# %%
ax = sb.heatmap(datos[["user_followers","user_friends","user_favourites"]])

# %% [markdown]
# Al ser las únicas variables númericas son las que usamos para el análisis.
